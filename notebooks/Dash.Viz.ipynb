# %%
import plotly.express as px
import plotly.figure_factory as ff
import pandas as pd
from dash import Dash,html,dcc,callback
from dash.dependencies import Input,Output,State

# %%
raw_df=pd.read_csv('../data/processed/EDA & Cleaning.csv')
df=raw_df.copy()

# %%
df.head()
# Out:
#    Unnamed: 0  patient_id  age  gender  visual_acuity_measurements    iop  \
# 0           0       62431   69    Male                         0.1  19.46
# 1           1       68125   69  Female                         0.1  18.39
# 2           2       63329   67  Female                         0.3  23.65
# 3           3       47174   23    Male                         0.0  18.04
# 4           4       67361   21    Male                         0.1  15.87
#
#     cdr family_history medical_history  \
# 0  0.42             No        Diabetes
# 1  0.72             No    Hypertension
# 2  0.72             No    Hypertension
# 3  0.61             No           other
# 4  0.30             No        Diabetes
#
#                                     medication_usage  ...  \
# 0  Amoxicillin, Lisinopril, Omeprazole, Atorvasta...  ...
# 1  Lisinopril, Amoxicillin, Atorvastatin, Ibuprof...  ...
# 2  Amoxicillin, Ibuprofen, Metformin, Atorvastati...  ...
# 3                                 Ibuprofen, Aspirin  ...
# 4  Amoxicillin, Omeprazole, Aspirin, Ibuprofen, A...  ...
#
#    angle_closure_status                                    visual_symptoms  \
# 0                  Open                    Tunnel vision, Eye pain, Nausea
# 1                  Open     Redness in the eye, Vision loss, Tunnel vision
# 2                Closed  Halos around lights, Vision loss, Redness in t...
# 3                Closed                Nausea, Nausea, Halos around lights
# 4                Closed                  Eye pain, Eye pain, Tunnel vision
#
#      diagnosis                glaucoma_type sensitivity specificity  \
# 0  No Glaucoma  Primary Open-Angle Glaucoma        0.54        0.75
# 1  No Glaucoma            Juvenile Glaucoma        0.72        0.88
# 2  No Glaucoma            Juvenile Glaucoma        0.56        0.80
# 3  No Glaucoma          Congenital Glaucoma        0.60        0.93
# 4  No Glaucoma  Primary Open-Angle Glaucoma        0.82        0.90
#
#    rnfl_thickness  gcc_thickness  retinal_volume  macular_thickness
# 0           86.48          64.14            5.63             283.67
# 1           96.88          56.48            5.69             261.48
# 2           89.81          59.05            5.96             282.34
# 3           87.25          63.98            6.44             262.86
# 4           82.61          66.01            6.16             261.78
#
# [5 rows x 22 columns]

# %%
# Q9 : Create a simple dash with the following:
'''
1- Create a plot that reflects the volume for a region during all months in diffrent years. 
2- Create a plot that reflects distribution of Average Price for a region during all months in diffrent years.
'''
app = dash.Dash()
app.layout = html.Div(
    [
        html.H1('Welcome To Avocado Prices Dashboard'),
        html.Div(
            dcc.Dropdown(
                id = 'region',
                options = [{'label':o, 'value':o} for o in df.region.unique()]
            )
        ),
        html.Div(
            [
                dcc.Graph(id = 'fig1')
            ]
        
        ),
        html.Div(
            [
                dcc.Graph(id = 'fig2')
            ]
        
        )
    ]
)
@app.callback(
    Output('fig1', 'figure'),
    Output('fig2', 'figure'),
    Input('region','value')
)

def get_updates(v):

    temp = df.loc[df.region == v, :]
    temp_fig1 = temp.groupby(['year', 'month'])['Total Volume'].sum().reset_index()
    temp_fig1.year = temp_fig1.year.apply(str)
    fig1 = px.bar(temp_fig1, x = 'month', y = 'Total Volume', barmode = 'group',color = 'year')
    fig2 = px.box(temp, x = 'month', y = 'AveragePrice', color = 'year')

    return (fig1, fig2)
app.run(jupyter_mode = 'external')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       1 # Q9 : Create a simple dash with the following:
#       2 '''
#       3 1- Create a plot that reflects the volume for a region during all months in diffrent years.
#       4 2- Create a plot that reflects distribution of Average Price for a region during all months in diffrent years.
#       5 '''
# ----> 6 app = dash.Dash()
#       7 app.layout = html.Div(
#       8     [
#       9         html.H1('Welcome To Avocado Prices Dashboard'),
#    (...)
#      28     ]
#      29 )
#      30 @app.callback(
#      31     Output('fig1', 'figure'),
#      32     Output('fig2', 'figure'),
#    (...)
#      35
#      36 def get_updates(v):
#
# NameError: name 'dash' is not defined

# %%
# Q9 : Create a simple dash with the following:
'''
1- Create a plot that reflects the volume for a region during all months in diffrent years. 
2- Create a plot that reflects distribution of Average Price for a region during all months in diffrent years.
'''
colors=['#dc2f02']
fig1=ff.create_distplot([df.age.to_list()],['age'],show_rug=False,colors=colors)
fig1.update_layout(title_text='Distribution of the Age')
fig1.update_xaxes(title_text='Age')
fig1.update_yaxes(title_text='Frequency')


fig2=px.histogram(df,x='age',facet_col='diagnosis')
fig2.update_layout(title='Highest Age through Glaucoma')


app = Dash()
app.layout = html.Div(
    [
        html.H1('Welcome To Glaucoma Detection Dashboard'),
        html.Div(
            dcc.Dropdown(
                id = 'gender',
                options = [{'label':o, 'value':o} for o in df.gender.unique()]
                
                
            )
        ),
        html.Div(
            [
                dcc.Graph(id='fig1',figure=fig1, style={'width': '48%','align': 'right', 'display': 'inline-block'}),
                dcc.Graph(id='fig2',figure=fig2, style={'width': '48%','align': 'right', 'display': 'inline-block'}),
                
                dcc.Graph(id = 'fig6', style={'width': '48%','align': 'right', 'display': 'inline-block'}),
                dcc.Graph(id = 'fig3', style={'width': '48%','align': 'right', 'display': 'inline-block'})
            ]
        
        ),
        html.Div(
            [
                dcc.Graph(id = 'fig10')
            ]
        
        )
    ]
)
@app.callback(
    Output('fig6', 'figure'),
    Output('fig3', 'figure'),
    Output('fig10', 'figure'),
    Input('gender','value')
)

def get_updates(v):

    temp = df.loc[df.gender == v, :]
    temp_fig1 = temp.groupby(['diagnosis', 'gender'])['patient_id'].count().reset_index()
    temp_fig1.diagnosis = temp_fig1.diagnosis.apply(str)
    fig6_out = px.bar(temp_fig1, x = 'diagnosis', y = 'patient_id', barmode = 'group',color = 'gender')
    fig3_out = px.pie(df, names='gender', title='Weight of Gender', color_discrete_sequence=px.colors.qualitative.Set1)
    fig10_out = px.box(temp, x = 'gender', y = 'patient_id')
    
    

    return (fig6_out, fig10_out,fig3_out)

app.run(jupyter_mode = 'external',port=2000)
# Out:
# Dash app running on http://127.0.0.1:2000/

# %%
import dash
from dash import dcc, html, callback, Output, Input
import plotly.express as px
import plotly.figure_factory as ff

# Assuming df is your DataFrame and colors is defined

# Create Dash app
app = dash.Dash(__name__)

# Your existing figures
fig1 = ff.create_distplot([df.age.to_list()], ['age'], show_rug=False, colors=colors)
fig1.update_layout(title_text='Distribution of the Age')
fig1.update_xaxes(title_text='Age')
fig1.update_yaxes(title_text='Frequency')

fig2 = px.histogram(df, x='age', facet_col='diagnosis')
fig2.update_layout(title='Highest Age through Glaucoma')

fig4 = px.histogram(df, x='family_history', y='patient_id', color='gender', histfunc='count',
                    color_discrete_sequence=px.colors.qualitative.Set1,
                    title='Count of Patients Grouped by Family History and Gender', text_auto=True,
                    labels={'family_history': 'Family History', 'count': 'Patient Count'})

fig5 = px.histogram(df, x='medical_history', facet_col='gender', text_auto=True, title='Highest Gender in Medical History')
fig5.update_yaxes(title_text='Patients Count')

fig_pie = px.pie(df, names='diagnosis', title='The Weight of Diagnosis',
                 color_discrete_sequence=px.colors.qualitative.Set1)
fig_pie.update_traces(textinfo='value+percent')

# Get unique genders and diagnoses for dropdown options
gender_options = [{'label': gender, 'value': gender} for gender in df['gender'].unique()]
diagnosis_options = [{'label': diagnosis, 'value': diagnosis} for diagnosis in df['diagnosis'].unique()]

# Layout of the dashboard
app.layout = html.Div(style={'textAlign': 'center'}, children=[
    html.H1("Interactive Healthcare Dashboard"),

    html.Div([
        # Dropdown for gender
        dcc.Dropdown(
            id='gender-dropdown',
            options=gender_options,
            value=df['gender'].unique()[0],  # Set default value
            style={'width': '50%'}
        ),

        # Dropdown for diagnosis
        dcc.Dropdown(
            id='diagnosis-dropdown',
            options=diagnosis_options,
            value=df['diagnosis'].unique()[0],  # Set default value
            style={'width': '50%'}
        ),
    ], style={'display': 'flex', 'justifyContent': 'center', 'margin': '20px'}),

    html.Div([
        # Distribution plot
        dcc.Graph(
            id='distplot',
            figure=fig1,
        ),
        # Histogram plot
        dcc.Graph(
            id='histogram',
            figure=fig2,
        ),
    ], style={'display': 'flex', 'justifyContent': 'space-around', 'margin': '20px'}),

    html.Div([
        # Additional Histogram plot (fig4)
        dcc.Graph(
            id='histogram-family-gender',
            figure=fig4,
        ),
        # Histogram plot for medical history by gender (fig5)
        dcc.Graph(
            id='histogram-medical-history',
            figure=fig5,
        ),
    ], style={'display': 'flex', 'justifyContent': 'space-around', 'margin': '20px'}),

    html.Div([
        # Pie chart for diagnosis (fig_pie)
        dcc.Graph(
            id='pie-chart-diagnosis',
            figure=fig_pie,
        ),
    ], style={'margin': '20px'}),

])


# Callbacks
@app.callback(
    Output('histogram-family-gender', 'figure'),
    [Input('gender-dropdown', 'value')]
)
def update_gender_histogram(selected_gender):
    filtered_df = df[(df['gender'] == selected_gender) & (df['diagnosis'] == app.layout['diagnosis-dropdown'].value)]
    updated_fig = px.histogram(filtered_df, x='family_history', y='patient_id', color='gender', histfunc='count',
                               color_discrete_sequence=px.colors.qualitative.Set1,
                               title=f'Count of Patients with Gender: {selected_gender}',
                               text_auto=True, labels={'family_history': 'Family History', 'count': 'Patient Count'})
    return updated_fig


@app.callback(
    Output('histogram-medical-history', 'figure'),
    [Input('gender-dropdown', 'value')]
)
def update_medical_history_histogram(selected_gender):
    filtered_df = df[(df['gender'] == selected_gender) & (df['diagnosis'] == app.layout['diagnosis-dropdown'].value)]
    updated_fig = px.histogram(filtered_df, x='medical_history', facet_col='gender', text_auto=True,
                               title=f'Highest Gender in Medical History for {selected_gender}')
    updated_fig.update_yaxes(title_text='Patients Count')
    return updated_fig


@app.callback(
    Output('distplot', 'figure'),
    [Input('gender-dropdown', 'value'), Input('diagnosis-dropdown', 'value')]
)
def update_distribution_plot(selected_gender, selected_diagnosis):
    filtered_df = df[(df['gender'] == selected_gender) & (df['diagnosis'] == selected_diagnosis)]
    updated_fig = ff.create_distplot([filtered_df.age.to_list()], ['age'], show_rug=False, colors=colors)
    updated_fig.update_layout(title_text='Distribution of the Age')
    updated_fig.update_xaxes(title_text='Age')
    updated_fig.update_yaxes(title_text='Frequency')
    return updated_fig


@app.callback(
    Output('histogram', 'figure'),
    [Input('diagnosis-dropdown', 'value')]
)
def update_diagnosis_histogram(selected_diagnosis):
    filtered_df = df[df['diagnosis'] == selected_diagnosis]
    updated_fig = px.histogram(filtered_df, x='age', facet_col='diagnosis')
    updated_fig.update_layout(title=f'Highest Age through {selected_diagnosis}')
    return updated_fig


@app.callback(
    Output('pie-chart-diagnosis', 'figure'),
    [Input('diagnosis-dropdown', 'value')]
)
def update_pie_chart(selected_diagnosis):
    filtered_df = df[df['diagnosis'] == selected_diagnosis]
    updated_fig = px.pie(filtered_df, names='diagnosis', title=f'The Weight of {selected_diagnosis}',
                         color_discrete_sequence=px.colors.qualitative.Set1)
    updated_fig.update_traces(textinfo='value+percent')
    return updated_fig


app.run(jupyter_mode = 'external',port=1000)
# Out:
# Dash app running on http://127.0.0.1:1000/
